# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import sklearn
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
data = pd.read_csv('data/cards.csv')
# Out:
# C:\Users\Przemyslaw\.conda\envs\mtg\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (6,9,12,16,40) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.describe()
# Out:
#               index            id  convertedManaCost    edhrecRank  \
# count  51430.000000  51430.000000       51430.000000  46925.000000
# mean   25714.500000  25715.500000          41.824178   8259.249462
# std    14846.706509  14846.706509        6235.930407   5970.205347
# min        0.000000      1.000000           0.000000      1.000000
# 25%    12857.250000  12858.250000           2.000000   2790.000000
# 50%    25714.500000  25715.500000           3.000000   7537.000000
# 75%    38571.750000  38572.750000           4.000000  13345.000000
# max    51429.000000  51430.000000     1000000.000000  19888.000000
#
#        faceConvertedManaCost        hand       hasFoil  hasNoDeckLimit  \
# count              877.00000  118.000000  51430.000000    51430.000000
# mean                 2.32041    0.084746      0.593253        0.000194
# std                  1.75463    1.209480      0.491232        0.013943
# min                  0.00000   -4.000000      0.000000        0.000000
# 25%                  1.00000   -1.000000      0.000000        0.000000
# 50%                  2.00000    0.000000      1.000000        0.000000
# 75%                  3.00000    1.000000      1.000000        0.000000
# max                  7.00000    3.000000      1.000000        1.000000
#
#          hasNonFoil  isAlternative  ...    isTextless  isTimeshifted  \
# count  51430.000000    51430.00000  ...  51430.000000   51430.000000
# mean       0.905717        0.00455  ...      0.001983       0.004103
# std        0.292226        0.06730  ...      0.044490       0.063921
# min        0.000000        0.00000  ...      0.000000       0.000000
# 25%        1.000000        0.00000  ...      0.000000       0.000000
# 50%        1.000000        0.00000  ...      0.000000       0.000000
# 75%        1.000000        0.00000  ...      0.000000       0.000000
# max        1.000000        1.00000  ...      1.000000       1.000000
#
#              life          mcmId      mcmMetaId    mtgArenaId    mtgoFoilId  \
# count  118.000000   38204.000000   38204.000000   3937.000000  24360.000000
# mean     1.135593  171711.050649   85372.130222  67745.773432  36910.388054
# std      5.679345  152975.960356  107841.046084   2134.511279  17398.227539
# min     -8.000000       1.000000       2.000000  62499.000000    303.000000
# 25%     -3.000000   11325.750000    3961.750000  65941.000000  21465.500000
# 50%      0.000000  247858.500000    8424.500000  68050.000000  36456.000000
# 75%      4.000000  293754.250000  208628.000000  69665.000000  52504.500000
# max     30.000000  455538.000000  302003.000000  70794.000000  70586.000000
#
#              mtgoId   multiverseId  tcgplayerProductId
# count  30247.000000   38886.000000        44412.000000
# mean   42044.965782  240077.594147        83002.825970
# std    20213.679846  178426.440084        70133.509127
# min        9.000000       1.000000           86.000000
# 25%    24236.000000   41132.250000        12812.750000
# 50%    41333.000000  226557.000000        71003.000000
# 75%    59392.000000  417603.750000       139939.250000
# max    80583.000000  484918.000000       212807.000000
#
# [8 rows x 33 columns]

# %%
data.head()
# Out:
#    index  id               artist asciiName borderColor colorIdentity  \
# 0      0   1         Rebecca Guay       NaN       black             G
# 1      1   2      Stephen Daniele       NaN       black             U
# 2      2   3            John Avon       NaN       black           U,W
# 3      3   4          Roger Raupp       NaN       black             B
# 4      4   5  Christopher Moeller       NaN       black             G
#
#   colorIndicator colors  convertedManaCost duelDeck  ...      subtypes  \
# 0            NaN      G                4.0      NaN  ...           NaN
# 1            NaN      U                3.0      NaN  ...  Human,Wizard
# 2            NaN    NaN                0.0      NaN  ...           NaN
# 3            NaN      B                3.0      NaN  ...           NaN
# 4            NaN      G                2.0      NaN  ...           NaN
#
#    supertypes tcgplayerProductId  \
# 0         NaN            15023.0
# 1         NaN            15024.0
# 2         NaN            15025.0
# 3         NaN            15026.0
# 4         NaN            15027.0
#
#                                                 text toughness  \
# 0  If you would draw a card, you may instead choo...       NaN
# 1  When Academy Researchers enters the battlefiel...         2
# 2  {T}: Add {C}.\n{T}: Add {W} or {U}. Adarkar Wa...       NaN
# 3  Target creature gets -1/-1 until end of turn.\...       NaN
# 4  Target creature gets +1/+1 until end of turn.\...       NaN
#
#                       type        types                                  uuid  \
# 0              Enchantment  Enchantment  1669af17-d287-5094-b005-4b143441442f
# 1  Creature — Human Wizard     Creature  047d5499-a21c-5f5c-9679-1599fcaf9815
# 2                     Land         Land  ee19938c-4007-58f1-8904-fae28007b422
# 3                  Instant      Instant  8774e18f-3752-5c06-af94-5da3960da9ed
# 4                  Instant      Instant  4e875bca-0c52-5d60-889d-1db67e261737
#
#    variations  watermark
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN
#
# [5 rows x 73 columns]

# %%
data.columns
# Out:
# Index(['index', 'id', 'artist', 'asciiName', 'borderColor', 'colorIdentity',
#        'colorIndicator', 'colors', 'convertedManaCost', 'duelDeck',
#        'edhrecRank', 'faceConvertedManaCost', 'flavorName', 'flavorText',
#        'frameEffect', 'frameEffects', 'frameVersion', 'hand', 'hasFoil',
#        'hasNoDeckLimit', 'hasNonFoil', 'isAlternative', 'isArena', 'isBuyABox',
#        'isDateStamped', 'isFullArt', 'isMtgo', 'isOnlineOnly', 'isOversized',
#        'isPaper', 'isPromo', 'isReprint', 'isReserved', 'isStarter',
#        'isStorySpotlight', 'isTextless', 'isTimeshifted', 'layout',
#        'leadershipSkills', 'life', 'loyalty', 'manaCost', 'mcmId', 'mcmMetaId',
#        'mtgArenaId', 'mtgoFoilId', 'mtgoId', 'multiverseId', 'name', 'names',
#        'number', 'originalText', 'originalType', 'otherFaceIds', 'power',
#        'printings', 'purchaseUrls', 'rarity', 'scryfallId',
#        'scryfallIllustrationId', 'scryfallOracleId', 'setCode', 'side',
#        'subtypes', 'supertypes', 'tcgplayerProductId', 'text', 'toughness',
#        'type', 'types', 'uuid', 'variations', 'watermark'],
#       dtype='object')

# %%
data['text']
# Out:
# 0        If you would draw a card, you may instead choo...
# 1        When Academy Researchers enters the battlefiel...
# 2        {T}: Add {C}.\n{T}: Add {W} or {U}. Adarkar Wa...
# 3        Target creature gets -1/-1 until end of turn.\...
# 4        Target creature gets +1/+1 until end of turn.\...
#                                ...
# 51425    Two target creatures you control each get +2/+...
# 51426    Flying\nLandfall — Whenever a land enters the ...
# 51427    At the beginning of your upkeep, you may choos...
# 51428    Landfall — Whenever a land enters the battlefi...
# 51429    Forestwalk (This creature can't be blocked as ...
# Name: text, Length: 51430, dtype: object

# %%
data_filtered = data[['asciiName', 'text', 'manaCost', 'power', 'life', 'rarity']]

# %%
data_filtered
# Out:
#       asciiName                                               text   manaCost  \
# 0           NaN  If you would draw a card, you may instead choo...  {2}{G}{G}
# 1           NaN  When Academy Researchers enters the battlefiel...  {1}{U}{U}
# 2           NaN  {T}: Add {C}.\n{T}: Add {W} or {U}. Adarkar Wa...        NaN
# 3           NaN  Target creature gets -1/-1 until end of turn.\...     {2}{B}
# 4           NaN  Target creature gets +1/+1 until end of turn.\...     {1}{G}
# ...         ...                                                ...        ...
# 51425       NaN  Two target creatures you control each get +2/+...  {2}{W}{W}
# 51426       NaN  Flying\nLandfall — Whenever a land enters the ...     {3}{U}
# 51427       NaN  At the beginning of your upkeep, you may choos...  {3}{W}{W}
# 51428       NaN  Landfall — Whenever a land enters the battlefi...     {1}{R}
# 51429       NaN  Forestwalk (This creature can't be blocked as ...     {4}{G}
#
#       power  life    rarity
# 0       NaN   NaN      rare
# 1         2   NaN  uncommon
# 2       NaN   NaN      rare
# 3       NaN   NaN    common
# 4       NaN   NaN    common
# ...     ...   ...       ...
# 51425   NaN   NaN  uncommon
# 51426     2   NaN    common
# 51427     4   NaN      rare
# 51428   NaN   NaN    common
# 51429     3   NaN    common
#
# [51430 rows x 6 columns]

# %% [markdown]
# ### Zamiania typu na string dla tokenizera

# %%
data_filtered['text'] = data_filtered['text'].astype(str)
# Out:
# C:\Users\Przemyslaw\.conda\envs\mtg\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tokenizer = Tokenizer(oov_token='<OOV>')
tokenizer.fit_on_texts(data_filtered['text'])

# %%
tokenizer.word_index
# Out:
# {'<OOV>': 1,
#  'the': 2,
#  'creature': 3,
#  'you': 4,
#  'a': 5,
#  'of': 6,
#  '1': 7,
#  'your': 8,
#  'target': 9,
#  'to': 10,
#  'this': 11,
#  'card': 12,
#  'it': 13,
#  'battlefield': 14,
#  't': 15,
#  'or': 16,
#  '2': 17,
#  'turn': 18,
#  'control': 19,
#  'and': 20,
#  'that': 21,
#  'damage': 22,
#  'enters': 23,
#  'if': 24,
#  'may': 25,
#  'put': 26,
#  'player': 27,
#  'with': 28,
#  'from': 29,
#  'end': 30,
#  'each': 31,
#  'on': 32,
#  'when': 33,
#  'add': 34,
#  'creatures': 35,
#  'library': 36,
#  'until': 37,
#  'as': 38,
#  'whenever': 39,
#  'cast': 40,
#  'flying': 41,
#  'for': 42,
#  'cards': 43,
#  'deals': 44,
#  'its': 45,
#  'hand': 46,
#  'spell': 47,
#  'an': 48,
#  'graveyard': 49,
#  'any': 50,
#  'at': 51,
#  '3': 52,
#  'counter': 53,
#  "can't": 54,
#  'gets': 55,
#  'life': 56,
#  'be': 57,
#  'sacrifice': 58,
#  'x': 59,
#  'draw': 60,
#  'mana': 61,
#  'then': 62,
#  'b': 63,
#  'cost': 64,
#  'r': 65,
#  'is': 66,
#  'g': 67,
#  'beginning': 68,
#  'exile': 69,
#  'land': 70,
#  'into': 71,
#  'u': 72,
#  'two': 73,
#  'destroy': 74,
#  'all': 75,
#  'return': 76,
#  'in': 77,
#  'w': 78,
#  'artifact': 79,
#  'their': 80,
#  'gain': 81,
#  'opponent': 82,
#  'top': 83,
#  'one': 84,
#  'create': 85,
#  'upkeep': 86,
#  'blocked': 87,
#  '0': 88,
#  'enchanted': 89,
#  '4': 90,
#  'combat': 91,
#  'tapped': 92,
#  'counters': 93,
#  'number': 94,
#  'untap': 95,
#  'pay': 96,
#  'token': 97,
#  'has': 98,
#  'choose': 99,
#  'by': 100,
#  'gains': 101,
#  'permanent': 102,
#  'enchant': 103,
#  'power': 104,
#  'other': 105,
#  'discard': 106,
#  'equal': 107,
#  'up': 108,
#  "owner's": 109,
#  'next': 110,
#  'step': 111,
#  'have': 112,
#  '—': 113,
#  'do': 114,
#  'controls': 115,
#  'more': 116,
#  'only': 117,
#  'get': 118,
#  'would': 119,
#  'shuffle': 120,
#  'three': 121,
#  'under': 122,
#  'onto': 123,
#  'c': 124,
#  'long': 125,
#  'reveal': 126,
#  'search': 127,
#  'trample': 128,
#  'dealt': 129,
#  'haste': 130,
#  'time': 131,
#  'becomes': 132,
#  'color': 133,
#  "it's": 134,
#  'first': 135,
#  'strike': 136,
#  'tap': 137,
#  'attacks': 138,
#  'another': 139,
#  'black': 140,
#  'ability': 141,
#  'can': 142,
#  '•': 143,
#  'are': 144,
#  'controller': 145,
#  'unless': 146,
#  'dies': 147,
#  'attack': 148,
#  'they': 149,
#  '5': 150,
#  'remove': 151,
#  'less': 152,
#  'green': 153,
#  'during': 154,
#  'white': 155,
#  'sorcery': 156,
#  'spells': 157,
#  'them': 158,
#  'block': 159,
#  'attacking': 160,
#  'instead': 161,
#  'face': 162,
#  'converted': 163,
#  'activate': 164,
#  'than': 165,
#  'way': 166,
#  'additional': 167,
#  'enchantment': 168,
#  'without': 169,
#  'except': 170,
#  'planeswalker': 171,
#  'red': 172,
#  'toughness': 173,
#  'abilities': 174,
#  'loses': 175,
#  'copy': 176,
#  'lands': 177,
#  'instant': 178,
#  'vigilance': 179,
#  'prevent': 180,
#  'discards': 181,
#  'tokens': 182,
#  'among': 183,
#  'where': 184,
#  'basic': 185,
#  'look': 186,
#  'no': 187,
#  'nan': 188,
#  'bottom': 189,
#  'reach': 190,
#  'defending': 191,
#  'four': 192,
#  'nonland': 193,
#  "creature's": 194,
#  'permanents': 195,
#  "player's": 196,
#  'those': 197,
#  'rest': 198,
#  'order': 199,
#  'type': 200,
#  'deal': 201,
#  'defender': 202,
#  'blue': 203,
#  'was': 204,
#  'goblin': 205,
#  "doesn't": 206,
#  'equipped': 207,
#  "don't": 208,
#  'lose': 209,
#  'chosen': 210,
#  'protection': 211,
#  'opponents': 212,
#  'equip': 213,
#  'blocking': 214,
#  'down': 215,
#  'costs': 216,
#  'colorless': 217,
#  'targets': 218,
#  'regenerate': 219,
#  'lifelink': 220,
#  'dragon': 221,
#  'sacrifices': 222,
#  'exiled': 223,
#  'choice': 224,
#  'paying': 225,
#  'flashback': 226,
#  'flash': 227,
#  'draws': 228,
#  'puts': 229,
#  'game': 230,
#  'greater': 231,
#  'artifacts': 232,
#  'regenerated': 233,
#  '6': 234,
#  'name': 235,
#  'untapped': 236,
#  'morph': 237,
#  'cycling': 238,
#  'random': 239,
#  'could': 240,
#  'pays': 241,
#  "that's": 242,
#  'deathtouch': 243,
#  'before': 244,
#  'forest': 245,
#  'indestructible': 246,
#  'zombie': 247,
#  'able': 248,
#  'charge': 249,
#  'five': 250,
#  'spirit': 251,
#  "isn't": 252,
#  'players': 253,
#  'blocks': 254,
#  'leaves': 255,
#  'seven': 256,
#  'noncreature': 257,
#  'total': 258,
#  'many': 259,
#  'play': 260,
#  'e': 261,
#  'scry': 262,
#  'swamp': 263,
#  'casts': 264,
#  'elemental': 265,
#  'island': 266,
#  'types': 267,
#  'reveals': 268,
#  'revealed': 269,
#  'there': 270,
#  'source': 271,
#  'wall': 272,
#  'double': 273,
#  'last': 274,
#  'still': 275,
#  "opponent's": 276,
#  'much': 277,
#  'not': 278,
#  'banding': 279,
#  'named': 280,
#  'human': 281,
#  '7': 282,
#  'non': 283,
#  'attach': 284,
#  'rather': 285,
#  'attached': 286,
#  'activated': 287,
#  'though': 288,
#  'both': 289,
#  'same': 290,
#  "spell's": 291,
#  "controller's": 292,
#  'flip': 293,
#  'addition': 294,
#  'hexproof': 295,
#  'mountain': 296,
#  'after': 297,
#  'kicked': 298,
#  'new': 299,
#  'aura': 300,
#  'menace': 301,
#  'amount': 302,
#  'paid': 303,
#  'sacrificed': 304,
#  'shuffles': 305,
#  'had': 306,
#  'nonblack': 307,
#  'own': 308,
#  'nontoken': 309,
#  'plains': 310,
#  'soldier': 311,
#  'vampire': 312,
#  'madness': 313,
#  'roll': 314,
#  'elf': 315,
#  'warrior': 316,
#  'angel': 317,
#  'saproling': 318,
#  'being': 319,
#  'age': 320,
#  'kicker': 321,
#  "card's": 322,
#  '−2': 323,
#  'countered': 324,
#  'beast': 325,
#  'while': 326,
#  'effect': 327,
#  'shroud': 328,
#  'graveyards': 329,
#  'phase': 330,
#  'legendary': 331,
#  'once': 332,
#  'destroyed': 333,
#  'knight': 334,
#  'otherwise': 335,
#  'spent': 336,
#  'chooses': 337,
#  'shadow': 338,
#  'level': 339,
#  'enter': 340,
#  'plus': 341,
#  'removed': 342,
#  'mutate': 343,
#  'spend': 344,
#  'win': 345,
#  'least': 346,
#  'giant': 347,
#  'echo': 348,
#  'divided': 349,
#  '8': 350,
#  'attacked': 351,
#  'base': 352,
#  'turned': 353,
#  'six': 354,
#  'form': 355,
#  "owners'": 356,
#  'chaos': 357,
#  'hydra': 358,
#  'die': 359,
#  'transform': 360,
#  'change': 361,
#  'causes': 362,
#  'hands': 363,
#  'emblem': 364,
#  'who': 365,
#  'devotion': 366,
#  '−3': 367,
#  "didn't": 368,
#  'exiles': 369,
#  'equipment': 370,
#  'enchantments': 371,
#  'fear': 372,
#  'also': 373,
#  'sliver': 374,
#  'arcane': 375,
#  'does': 376,
#  'ten': 377,
#  'monstrous': 378,
#  'evoke': 379,
#  'anywhere': 380,
#  'steps': 381,
#  'excess': 382,
#  'colors': 383,
#  'storm': 384,
#  'wolf': 385,
#  'lightning': 386,
#  'were': 387,
#  'cycle': 388,
#  'rounded': 389,
#  '10': 390,
#  'comes': 391,
#  'become': 392,
#  'creates': 393,
#  'times': 394,
#  'either': 395,
#  'remains': 396,
#  'landfall': 397,
#  'islands': 398,
#  'bands': 399,
#  'controlled': 400,
#  'resolves': 401,
#  'champion': 402,
#  'islandwalk': 403,
#  'swampwalk': 404,
#  'phyrexian': 405,
#  'fire': 406,
#  'enough': 407,
#  'casting': 408,
#  'half': 409,
#  'golem': 410,
#  'cause': 411,
#  'merfolk': 412,
#  'dead': 413,
#  "urza's": 414,
#  'soon': 415,
#  'main': 416,
#  'effects': 417,
#  'deck': 418,
#  'coin': 419,
#  "turn's": 420,
#  'nonartifact': 421,
#  'commander': 422,
#  'twice': 423,
#  'poison': 424,
#  'mage': 425,
#  'band': 426,
#  'share': 427,
#  'devoid': 428,
#  'since': 429,
#  'unearth': 430,
#  'cumulative': 431,
#  'clockwork': 432,
#  'snow': 433,
#  'wurm': 434,
#  "you're": 435,
#  'rats': 436,
#  'group': 437,
#  'targeted': 438,
#  'temple': 439,
#  'pile': 440,
#  'owner': 441,
#  'eldrazi': 442,
#  'returns': 443,
#  'loyalty': 444,
#  'say': 445,
#  'forestwalk': 446,
#  'text': 447,
#  'troll': 448,
#  'prevented': 449,
#  'war': 450,
#  'nonbasic': 451,
#  'help': 452,
#  'partner': 453,
#  'horsemanship': 454,
#  'attackers': 455,
#  'threshold': 456,
#  'back': 457,
#  'lost': 458,
#  '−8': 459,
#  'alone': 460,
#  'came': 461,
#  'mine': 462,
#  'mountains': 463,
#  'starting': 464,
#  'fights': 465,
#  'suspend': 466,
#  'divide': 467,
#  '−1': 468,
#  'copies': 469,
#  'swamps': 470,
#  'forests': 471,
#  'size': 472,
#  'ally': 473,
#  "they're": 474,
#  "you've": 475,
#  '−7': 476,
#  'zone': 477,
#  'blessing': 478,
#  'beyond': 479,
#  'second': 480,
#  'extra': 481,
#  'vault': 482,
#  'adds': 483,
#  'declared': 484,
#  'kind': 485,
#  'unblocked': 486,
#  'megamorph': 487,
#  'energy': 488,
#  'chandra': 489,
#  'pit': 490,
#  'maximum': 491,
#  'out': 492,
#  'shaman': 493,
#  'shares': 494,
#  'command': 495,
#  'demon': 496,
#  'been': 497,
#  'discarded': 498,
#  'greatest': 499,
#  'flame': 500,
#  'lasts': 501,
#  'phantom': 502,
#  'myr': 503,
#  'exchange': 504,
#  'storage': 505,
#  'most': 506,
#  'blood': 507,
#  'indefinitely': 508,
#  'remain': 509,
#  'exactly': 510,
#  'flanking': 511,
#  'faerie': 512,
#  'renowned': 513,
#  'spore': 514,
#  "land's": 515,
#  'take': 516,
#  'drake': 517,
#  'quest': 518,
#  'thopter': 519,
#  'bestow': 520,
#  'fade': 521,
#  "aren't": 522,
#  'p': 523,
#  'changeling': 524,
#  'scheme': 525,
#  'so': 526,
#  'spider': 527,
#  'convoke': 528,
#  'but': 529,
#  'soul': 530,
#  'bird': 531,
#  'iii': 532,
#  'zombies': 533,
#  'horror': 534,
#  'piles': 535,
#  'splice': 536,
#  'manifest': 537,
#  'phases': 538,
#  'playing': 539,
#  'died': 540,
#  'entwine': 541,
#  'cat': 542,
#  'leave': 543,
#  'refuge': 544,
#  'infect': 545,
#  'instances': 546,
#  'anything': 547,
#  'living': 548,
#  'tied': 549,
#  'every': 550,
#  'guildgate': 551,
#  'later': 552,
#  'blast': 553,
#  'planeswalkers': 554,
#  'spike': 555,
#  "city's": 556,
#  'single': 557,
#  'over': 558,
#  'skip': 559,
#  'different': 560,
#  'mountainwalk': 561,
#  'turns': 562,
#  'eye': 563,
#  'centaur': 564,
#  'specter': 565,
#  'serpent': 566,
#  'plant': 567,
#  'stone': 568,
#  'sengir': 569,
#  'assigns': 570,
#  'outside': 571,
#  'intimidate': 572,
#  'fewer': 573,
#  'already': 574,
#  'rogue': 575,
#  'vivid': 576,
#  'army': 577,
#  'word': 578,
#  'insect': 579,
#  'treasure': 580,
#  'minus': 581,
#  'doom': 582,
#  'ancient': 583,
#  'prowess': 584,
#  'wizard': 585,
#  'lore': 586,
#  'titan': 587,
#  'exalted': 588,
#  'third': 589,
#  'kavu': 590,
#  'hellkite': 591,
#  "planeswalker's": 592,
#  'produce': 593,
#  'thallid': 594,
#  'example': 595,
#  'walls': 596,
#  'ghoul': 597,
#  'ogre': 598,
#  'elves': 599,
#  'lord': 600,
#  'replacing': 601,
#  'guardian': 602,
#  'avatar': 603,
#  'fiend': 604,
#  'vehicle': 605,
#  'sided': 606,
#  "controllers'": 607,
#  'pirate': 608,
#  'plague': 609,
#  'aether': 610,
#  '−6': 611,
#  'rakdos': 612,
#  'ward': 613,
#  'ice': 614,
#  'overload': 615,
#  'taps': 616,
#  'process': 617,
#  'give': 618,
#  'move': 619,
#  'sphinx': 620,
#  'monstrosity': 621,
#  'historic': 622,
#  'motion': 623,
#  'guard': 624,
#  'repeat': 625,
#  'stack': 626,
#  'animate': 627,
#  "artifact's": 628,
#  'again': 629,
#  'death': 630,
#  's': 631,
#  'ante': 632,
#  'boros': 633,
#  'golgari': 634,
#  'proliferate': 635,
#  'spawn': 636,
#  'sea': 637,
#  'egg': 638,
#  'phoenix': 639,
#  'cascade': 640,
#  'dash': 641,
#  'set': 642,
#  'colossus': 643,
#  'elvish': 644,
#  'djinn': 645,
#  'attacker': 646,
#  'dinosaur': 647,
#  'votes': 648,
#  'hunter': 649,
#  'assembly': 650,
#  'eternal': 651,
#  'ooze': 652,
#  'treefolk': 653,
#  'kor': 654,
#  'ninjutsu': 655,
#  'delirium': 656,
#  'mutates': 657,
#  'hatchling': 658,
#  'auras': 659,
#  'bolt': 660,
#  'elder': 661,
#  'multicolored': 662,
#  'transforms': 663,
#  'yavimaya': 664,
#  'surge': 665,
#  'totem': 666,
#  'libraries': 667,
#  'gideon': 668,
#  'armor': 669,
#  'dragons': 670,
#  'represents': 671,
#  'orcish': 672,
#  'shivan': 673,
#  'combination': 674,
#  'tower': 675,
#  'paired': 676,
#  'buyback': 677,
#  'kithkin': 678,
#  'snake': 679,
#  'left': 680,
#  'servo': 681,
#  'crew': 682,
#  'slivers': 683,
#  'food': 684,
#  'unspent': 685,
#  'izzet': 686,
#  'bloodthirst': 687,
#  'river': 688,
#  'symbols': 689,
#  'ring': 690,
#  'imp': 691,
#  'growth': 692,
#  'counts': 693,
#  'replicate': 694,
#  'mire': 695,
#  'efreet': 696,
#  'worker': 697,
#  'master': 698,
#  'captain': 699,
#  'veteran': 700,
#  'goblins': 701,
#  'werewolf': 702,
#  'highest': 703,
#  'returned': 704,
#  'must': 705,
#  'miracle': 706,
#  'heroic': 707,
#  'phantasmal': 708,
#  'city': 709,
#  'heart': 710,
#  'putting': 711,
#  'juggernaut': 712,
#  'assign': 713,
#  "weren't": 714,
#  'carrion': 715,
#  'regular': 716,
#  'bolas': 717,
#  'rat': 718,
#  'embalm': 719,
#  'jungle': 720,
#  'azorius': 721,
#  'draft': 722,
#  'fuse': 723,
#  'sources': 724,
#  'scion': 725,
#  'thrull': 726,
#  'wilds': 727,
#  'shrine': 728,
#  'dimir': 729,
#  'monarch': 730,
#  'whelp': 731,
#  'imprint': 732,
#  'start': 733,
#  'multikicker': 734,
#  'fiery': 735,
#  'rebound': 736,
#  'escape': 737,
#  'elite': 738,
#  'arrows': 739,
#  'lava': 740,
#  'siege': 741,
#  'declare': 742,
#  'produced': 743,
#  'ghost': 744,
#  'ebon': 745,
#  'landcycling': 746,
#  'god': 747,
#  'elephant': 748,
#  'toward': 749,
#  'persist': 750,
#  'constellation': 751,
#  'delve': 752,
#  'contraption': 753,
#  'deep': 754,
#  'gargoyle': 755,
#  'icatian': 756,
#  'wind': 757,
#  'undying': 758,
#  'gate': 759,
#  'grove': 760,
#  'gruul': 761,
#  'discarding': 762,
#  'metalcraft': 763,
#  'dredge': 764,
#  'sage': 765,
#  'unchanged': 766,
#  "gaea's": 767,
#  'dwarven': 768,
#  'lesser': 769,
#  'scourge': 770,
#  "permanent's": 771,
#  'serrated': 772,
#  'rage': 773,
#  'i': 774,
#  'rock': 775,
#  'affinity': 776,
#  'dark': 777,
#  'sanctuary': 778,
#  'paladin': 779,
#  'domain': 780,
#  'simic': 781,
#  'clue': 782,
#  'ii': 783,
#  'result': 784,
#  'aven': 785,
#  'shade': 786,
#  'brass': 787,
#  'battle': 788,
#  'inferno': 789,
#  'marsh': 790,
#  'cinder': 791,
#  'krosan': 792,
#  'companion': 793,
#  'desert': 794,
#  'wild': 795,
#  'familiar': 796,
#  'selesnya': 797,
#  'entered': 798,
#  'outlast': 799,
#  'investigate': 800,
#  'planeswalk': 801,
#  'kjeldoran': 802,
#  'ship': 803,
#  "won't": 804,
#  'exert': 805,
#  'separates': 806,
#  'arrowhead': 807,
#  'wither': 808,
#  'burning': 809,
#  'saga': 810,
#  'sentinel': 811,
#  "wasn't": 812,
#  'volcanic': 813,
#  'clash': 814,
#  'mystic': 815,
#  'artist': 816,
#  'orzhov': 817,
#  'crag': 818,
#  'populate': 819,
#  'raid': 820,
#  'names': 821,
#  'tide': 822,
#  'pack': 823,
#  'crank': 824,
#  'mogg': 825,
#  'blockers': 826,
#  'will': 827,
#  'man': 828,
#  'cleric': 829,
#  'sphere': 830,
#  'hero': 831,
#  'hidden': 832,
#  '20': 833,
#  'true': 834,
#  'flames': 835,
#  'aftermath': 836,
#  'annihilator': 837,
#  'ki': 838,
#  "commander's": 839,
#  'higher': 840,
#  'surveil': 841,
#  '9': 842,
#  'whose': 843,
#  'liege': 844,
#  'scavenging': 845,
#  'primal': 846,
#  'shield': 847,
#  'ruins': 848,
#  'nonwhite': 849,
#  'sun': 850,
#  'mastery': 851,
#  'devour': 852,
#  '−x': 853,
#  'bushido': 854,
#  'identity': 855,
#  'q': 856,
#  'transmute': 857,
#  'construct': 858,
#  'orb': 859,
#  'lich': 860,
#  'begin': 861,
#  'hollow': 862,
#  'griffin': 863,
#  'crypt': 864,
#  'druid': 865,
#  'forgotten': 866,
#  'feeder': 867,
#  'split': 868,
#  'experience': 869,
#  'priest': 870,
#  'squirrel': 871,
#  'conspiracy': 872,
#  'ascend': 873,
#  'escape—': 874,
#  'nantuko': 875,
#  'spark': 876,
#  "mishra's": 877,
#  'oracle': 878,
#  'bog': 879,
#  'knowledge': 880,
#  'wish': 881,
#  'spellbomb': 882,
#  'thief': 883,
#  'emissary': 884,
#  'phased': 885,
#  'exist': 886,
#  'opening': 887,
#  'fading': 888,
#  'sentry': 889,
#  'y': 890,
#  'tomb': 891,
#  'keldon': 892,
#  'minotaur': 893,
#  'herald': 894,
#  'activating': 895,
#  'tranquil': 896,
#  'mentor': 897,
#  'savage': 898,
#  'grave': 899,
#  'chamber': 900,
#  'molten': 901,
#  'burst': 902,
#  'treated': 903,
#  'renown': 904,
#  'cavalier': 905,
#  'depletion': 906,
#  'augment': 907,
#  'owns': 908,
#  'ruin': 909,
#  'evenly': 910,
#  'thicket': 911,
#  'battery': 912,
#  'shapeshifter': 913,
#  'switch': 914,
#  'high': 915,
#  'exerted': 916,
#  'him': 917,
#  '−10': 918,
#  'blade': 919,
#  'distribute': 920,
#  '4—': 921,
#  'butcher': 922,
#  'bolster': 923,
#  'ferocious': 924,
#  'symbol': 925,
#  'star': 926,
#  'engine': 927,
#  'corpse': 928,
#  'rampage': 929,
#  'diamond': 930,
#  'difference': 931,
#  'fury': 932,
#  'bat': 933,
#  'falls': 934,
#  'triggered': 935,
#  'spire': 936,
#  'ranger': 937,
#  'tyrant': 938,
#  'field': 939,
#  'wins': 940,
#  'battlemage': 941,
#  'morbid': 942,
#  'amass': 943,
#  'bottle': 944,
#  'twenty': 945,
#  'pyromancer': 946,
#  'masticore': 947,
#  'skeleton': 948,
#  'village': 949,
#  'monolith': 950,
#  'lotus': 951,
#  'cursed': 952,
#  'sorcerer': 953,
#  'simulacrum': 954,
#  'avenger': 955,
#  'hammer': 956,
#  'precombat': 957,
#  'nicol': 958,
#  'guide': 959,
#  '−9': 960,
#  'duplicant': 961,
#  '3—': 962,
#  'halves': 963,
#  'bogardan': 964,
#  'mind': 965,
#  'ravenous': 966,
#  'expanse': 967,
#  'personal': 968,
#  'clock': 969,
#  'justice': 970,
#  'dream': 971,
#  'boar': 972,
#  'fight': 973,
#  'support': 974,
#  'rot': 975,
#  'fate': 976,
#  'farm': 977,
#  'scavenge': 978,
#  'hedge': 979,
#  'vote': 980,
#  'howling': 981,
#  'strider': 982,
#  'gang': 983,
#  'fireball': 984,
#  'pestilence': 985,
#  'between': 986,
#  'unattached': 987,
#  'fallen': 988,
#  'charm': 989,
#  'dread': 990,
#  'midnight': 991,
#  'garrison': 992,
#  'ninja': 993,
#  'hour': 994,
#  'council': 995,
#  'transformed': 996,
#  'legendaries': 997,
#  'sagas': 998,
#  'eternalize': 999,
#  'prowl': 1000,
#  ...}
